# %%
# !pip install tensorflow==2.5.0 tensorflow-gpu==2.5.0 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: tensorflow-gpu==2.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: opencv-python in c:\users\lenovo\anaconda3\lib\site-packages (4.5.5.64)
# Requirement already satisfied: mediapipe in c:\users\lenovo\anaconda3\lib\site-packages (0.8.10)
# Requirement already satisfied: sklearn in c:\users\lenovo\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: matplotlib in c:\users\lenovo\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (3.7.4.3)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (2.5.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (3.19.4)
# Requirement already satisfied: absl-py~=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (0.15.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.19.5)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.34.1)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (0.2.0)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (2.9.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.15.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (2.5.0.dev2021032900)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (0.37.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow==2.5.0) (1.12.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\lenovo\anaconda3\lib\site-packages (from mediapipe) (4.5.5.64)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (58.0.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.6.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.7.1)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.54116839,  0.30061477, -0.84770489, ...,  0.19025655,
#         0.37494168, -0.04907141])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.54116839,  0.30061477, -0.84770489, ...,  0.19025655,
#         0.37494168, -0.04907141])

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 1

# Videos are going to be 30 frames in length
sequence_length = 1

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (3, 1, 1662)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (3, 1, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
y
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (1, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.2, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'hello'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# WARNING:tensorflow:Model was constructed with shape (None, 30, 1662) for input KerasTensor(type_spec=TensorSpec(shape=(None, 30, 1662), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1662).
# WARNING:tensorflow:Model was constructed with shape (None, 30, 1662) for input KerasTensor(type_spec=TensorSpec(shape=(None, 30, 1662), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1662).
# 1/1 [==============================] - 2s 2s/step - loss: 1.0980 - categorical_accuracy: 0.5000
# Epoch 2/2000
# 1/1 [==============================] - 0s 89ms/step - loss: 1.0938 - categorical_accuracy: 0.5000
# Epoch 3/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0882 - categorical_accuracy: 0.5000
# Epoch 4/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0816 - categorical_accuracy: 0.5000
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0728 - categorical_accuracy: 0.5000
# Epoch 6/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0616 - categorical_accuracy: 0.5000
# Epoch 7/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0472 - categorical_accuracy: 0.5000
# Epoch 8/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0293 - categorical_accuracy: 0.5000
# Epoch 9/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0077 - categorical_accuracy: 0.5000
# Epoch 10/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9796 - categorical_accuracy: 0.5000
# Epoch 11/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9460 - categorical_accuracy: 0.5000
# Epoch 12/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9066 - categorical_accuracy: 0.5000
# Epoch 13/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8566 - categorical_accuracy: 0.5000
# Epoch 14/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8008 - categorical_accuracy: 0.5000
# Epoch 15/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7387 - categorical_accuracy: 0.5000
# Epoch 16/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6648 - categorical_accuracy: 0.5000
# Epoch 17/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5861 - categorical_accuracy: 1.0000
# Epoch 18/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4977 - categorical_accuracy: 1.0000
# Epoch 19/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4145 - categorical_accuracy: 1.0000
# Epoch 20/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3371 - categorical_accuracy: 1.0000
# Epoch 21/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2619 - categorical_accuracy: 1.0000
# Epoch 22/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1791 - categorical_accuracy: 1.0000
# Epoch 23/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1207 - categorical_accuracy: 1.0000
# Epoch 24/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0776 - categorical_accuracy: 1.0000
# Epoch 25/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0382 - categorical_accuracy: 1.0000
# Epoch 26/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0213 - categorical_accuracy: 1.0000
# Epoch 27/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0092 - categorical_accuracy: 1.0000
# Epoch 28/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 29/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 30/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 9.0710e-04 - categorical_accuracy: 1.0000
# Epoch 31/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9667e-04 - categorical_accuracy: 1.0000
# Epoch 32/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.5809e-04 - categorical_accuracy: 1.0000
# Epoch 33/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2736e-04 - categorical_accuracy: 1.0000
# Epoch 34/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0376e-05 - categorical_accuracy: 1.0000
# Epoch 35/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8073e-05 - categorical_accuracy: 1.0000
# Epoch 36/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3053e-05 - categorical_accuracy: 1.0000
# Epoch 37/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3181e-06 - categorical_accuracy: 1.0000
# Epoch 38/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1590e-06 - categorical_accuracy: 1.0000
# Epoch 39/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6093e-06 - categorical_accuracy: 1.0000
# Epoch 40/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3446e-07 - categorical_accuracy: 1.0000
# Epoch 41/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7684e-07 - categorical_accuracy: 1.0000
# Epoch 42/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3842e-07 - categorical_accuracy: 1.0000
# Epoch 43/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1921e-07 - categorical_accuracy: 1.0000
# Epoch 44/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9605e-08 - categorical_accuracy: 1.0000
# Epoch 45/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.9605e-08 - categorical_accuracy: 1.0000
# Epoch 46/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9605e-08 - categorical_accuracy: 1.0000
# Epoch 47/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 48/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 49/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 50/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 51/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 52/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 53/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 54/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 55/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 56/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 57/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 58/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 59/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 60/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 61/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 62/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 63/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 64/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 65/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 66/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 67/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 68/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 69/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 70/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 71/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 72/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 73/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 74/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 75/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 76/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 77/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 78/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 79/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 80/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 81/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 82/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 83/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 84/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 85/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 86/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 87/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 88/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 89/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 90/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 91/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 92/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 93/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 94/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 95/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 96/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 97/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 98/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 99/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 100/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 101/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 102/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 103/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 104/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 105/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 106/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 107/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 108/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 109/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 110/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 111/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 112/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 113/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 114/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 115/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 116/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 117/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 118/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 119/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 120/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 121/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 122/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 123/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 124/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 125/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 126/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 127/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 128/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 129/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 130/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 131/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 132/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 133/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 134/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 135/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 136/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 137/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 138/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 139/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 140/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 141/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 142/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 143/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 144/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 145/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 146/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 147/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 148/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 149/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 150/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 151/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 152/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 153/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 154/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 155/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 156/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 157/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 158/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 159/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 160/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 161/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 162/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 163/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 164/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 165/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 166/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 167/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 168/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 169/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 170/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 171/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 172/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 173/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 174/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 175/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 176/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 177/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 178/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 179/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 180/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 181/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 182/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 183/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 184/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 185/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 186/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 187/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 188/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 189/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 190/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 191/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 192/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 193/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 194/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 195/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 196/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 197/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 198/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 199/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 200/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 201/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 202/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 203/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 204/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 205/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 206/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 207/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 208/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 209/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 210/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 211/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 212/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 213/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 214/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 215/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 216/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 217/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 218/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 219/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 220/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 221/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 222/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 223/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 224/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 225/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 226/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 227/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 228/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 229/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 230/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 231/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 232/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 233/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 234/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 235/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 236/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 237/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 238/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 239/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 240/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 241/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 242/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 243/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 244/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 245/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 246/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 247/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 248/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 249/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 250/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 251/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 252/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 253/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 254/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 255/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 256/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 257/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 258/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 259/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 260/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 261/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 262/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 263/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 264/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 265/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 266/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 267/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 268/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 269/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 270/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 271/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 272/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 273/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 274/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 275/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 276/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 277/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 278/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 279/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 280/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 281/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 282/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 283/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 284/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 285/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 286/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 287/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 288/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 289/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 290/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 291/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 292/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 293/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 294/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 295/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 296/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 297/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 298/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 299/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 300/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 301/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 302/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 303/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 304/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 305/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 306/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 307/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 308/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 309/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 310/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 311/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 312/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 313/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 314/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 315/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 316/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 317/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 318/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 319/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 320/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 321/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 322/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 323/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 324/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 325/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 326/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 327/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 328/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 329/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 330/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 331/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 332/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 333/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 334/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 335/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 336/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 337/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 338/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 339/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 340/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 341/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 342/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 343/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 344/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 345/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 346/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 347/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 348/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 349/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 350/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 351/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 352/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 353/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 354/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 355/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 356/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 357/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 358/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 359/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 360/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 361/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 362/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 363/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 364/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 365/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 366/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 367/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 368/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 369/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 370/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 371/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 372/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 373/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 374/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 375/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 376/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 377/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 378/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 379/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 380/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 381/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 382/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 383/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 384/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 385/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 386/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 387/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 388/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 389/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 390/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 391/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 392/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 393/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 394/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 395/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 396/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 397/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 398/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 399/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 400/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 401/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 402/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 403/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 404/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 405/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 406/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 407/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 408/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 409/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 410/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 411/2000
# ...
# Epoch 1865/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1866/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 30, 1662) for input KerasTensor(type_spec=TensorSpec(shape=(None, 30, 1662), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1662).

# %%
actions[np.argmax(res[0])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'iloveyou'

# %%
model.save('action.h5')

# %%
del model

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))

# %%
#sequence.append('def')

# %%
#sequence.reverse()

# %%
sequence = []
sentence = []
threshold = 0.8

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        # sequence.append(keypoints)
       # sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
         # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
cap.release()
cv2.destroyAllWindows()
